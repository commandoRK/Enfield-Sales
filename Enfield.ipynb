# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("/content/royalenfield.xlsx")

# %%
df
# Out:
#          Date  Sales
# 0  2018-01-01  76205
# 1  2018-02-01  71354
# 2  2018-03-01  74209
# 3  2018-04-01  74627
# 4  2018-05-01  72510
# ..        ...    ...
# 67 2023-08-01  69393
# 68 2023-09-01  78580
# 69 2023-10-01  84435
# 70 2023-11-01  75137
# 71 2023-12-01  57291
#
# [72 rows x 2 columns]

# %%
df=df.rename(columns={"Date":'ds',"Sales":'y'})

# %%
df
# Out:
#            ds      y
# 0  2018-01-01  76205
# 1  2018-02-01  71354
# 2  2018-03-01  74209
# 3  2018-04-01  74627
# 4  2018-05-01  72510
# ..        ...    ...
# 67 2023-08-01  69393
# 68 2023-09-01  78580
# 69 2023-10-01  84435
# 70 2023-11-01  75137
# 71 2023-12-01  57291
#
# [72 rows x 2 columns]

# %%
def remove_outliers_iqr(df, column):
    Q1 = df[column].quantile(0.28)
    Q3 = df[column].quantile(0.78)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]
df1=remove_outliers_iqr(df,'y')

# %%
df1
# Out:
#            ds      y
# 0  2018-01-01  76205
# 1  2018-02-01  71354
# 2  2018-03-01  74209
# 3  2018-04-01  74627
# 4  2018-05-01  72510
# ..        ...    ...
# 67 2023-08-01  69393
# 68 2023-09-01  78580
# 69 2023-10-01  84435
# 70 2023-11-01  75137
# 71 2023-12-01  57291
#
# [68 rows x 2 columns]

# %%
from prophet import Prophet

# %%
model=Prophet()

# %%
model.fit(df1)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/9zefx72b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/wt2a5t38.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98950', 'data', 'file=/tmp/tmphtb_b57b/9zefx72b.json', 'init=/tmp/tmphtb_b57b/wt2a5t38.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modelmoqyveyf/prophet_model-20240618065141.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:51:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future=model.make_future_dataframe(periods=12, freq='M')

# %%
forecast=model.predict(future)

# %%
forecast
# Out:
#            ds         trend    yhat_lower     yhat_upper   trend_lower  \
# 0  2018-01-01  69231.380595  65924.077696   82519.025581  69231.380595
# 1  2018-02-01  68773.891477  62099.967239   79039.457602  68773.891477
# 2  2018-03-01  68360.675500  57784.504191   73765.587314  68360.675500
# 3  2018-04-01  67903.186358  56941.755865   73201.810457  67903.186358
# 4  2018-05-01  67460.454930  67260.664247   84238.003924  67460.454930
# ..        ...           ...           ...            ...           ...
# 75 2024-07-31  80032.380663  64530.614528   80723.205937  79479.555870
# 76 2024-08-31  80697.069301  72184.924511   88267.918468  80028.109589
# 77 2024-09-30  81340.316369  84520.429007  100646.881608  80581.653812
# 78 2024-10-31  82005.005007  76051.782613   91587.978751  81129.218384
# 79 2024-11-30  82648.252076  56103.516057   72414.754132  81647.096684
#
#      trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0   69231.380595     4537.189028           4537.189028           4537.189028
# 1   68773.891477     2018.575794           2018.575794           2018.575794
# 2   68360.675500    -2831.240998          -2831.240998          -2831.240998
# 3   67903.186358    -2660.608995          -2660.608995          -2660.608995
# 4   67460.454930     8213.920678           8213.920678           8213.920678
# ..           ...             ...                   ...                   ...
# 75  80551.480638    -7518.249346          -7518.249346          -7518.249346
# 76  81324.123135     -603.034963           -603.034963           -603.034963
# 77  82065.785639    11023.673582          11023.673582          11023.673582
# 78  82862.153718     1843.138624           1843.138624           1843.138624
# 79  83627.991972   -18202.086226         -18202.086226         -18202.086226
#
#           yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0    4537.189028   4537.189028   4537.189028                   0.0
# 1    2018.575794   2018.575794   2018.575794                   0.0
# 2   -2831.240998  -2831.240998  -2831.240998                   0.0
# 3   -2660.608995  -2660.608995  -2660.608995                   0.0
# 4    8213.920678   8213.920678   8213.920678                   0.0
# ..           ...           ...           ...                   ...
# 75  -7518.249346  -7518.249346  -7518.249346                   0.0
# 76   -603.034963   -603.034963   -603.034963                   0.0
# 77  11023.673582  11023.673582  11023.673582                   0.0
# 78   1843.138624   1843.138624   1843.138624                   0.0
# 79 -18202.086226 -18202.086226 -18202.086226                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper          yhat
# 0                          0.0                         0.0  73768.569623
# 1                          0.0                         0.0  70792.467271
# 2                          0.0                         0.0  65529.434502
# 3                          0.0                         0.0  65242.577363
# 4                          0.0                         0.0  75674.375608
# ..                         ...                         ...           ...
# 75                         0.0                         0.0  72514.131318
# 76                         0.0                         0.0  80094.034338
# 77                         0.0                         0.0  92363.989951
# 78                         0.0                         0.0  83848.143631
# 79                         0.0                         0.0  64446.165850
#
# [80 rows x 16 columns]

# %%
y_pred=forecast['yhat'][:len(df1)]

# %%
y_true=df1['y']

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_true,y_pred)
# Out:
# 0.6990899718256531

# %%
from prophet.plot import plot_plotly,plot_components_plotly

# %%
plot_plotly(model,forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="eb64b644-ace4-49f5-8b49-bcad0a5a751a" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb64b644-ace4-49f5-8b49-bcad0a5a751a")) {                    Plotly.newPlot(                        "eb64b644-ace4-49f5-8b49-bcad0a5a751a",                        [{"marker":{"color":"black","size":4},"mode":"markers","name":"Actual","x":["2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00"],"y":[76205,71354,74209,74627,72510,72588,67001,68014,70065,70044,65026,56026,70872,60066,58434,59137,60211,55082,49092,48752,54874,67538,58292,48489,61292,61188,32630,37925,37925,47571,55910,62858,59084,65492,64372,65114,60173,48789,35815,39290,39070,40611,44830,65187,58838,59160,67677,53852,63643,61407,55555,61982,73646,76528,70766,68400,74746,71544,59884,68881,77461,77109,66062,69393,78580,84435,75137,57291],"type":"scatter"},{"hoverinfo":"skip","line":{"width":0},"mode":"lines","x":["2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07 ...

# %%
plot_components_plotly(model,forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="98d0a650-3f17-4a2c-9a8b-df8a837a049b" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98d0a650-3f17-4a2c-9a8b-df8a837a049b")) {                    Plotly.newPlot(                        "98d0a650-3f17-4a2c-9a8b-df8a837a049b",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00","2020-01-01T00:00:00","2020-02-01T00:00:00","2020-03-01T00:00:00","2020-06-01T00:00:00","2020-07-01T00:00:00","2020-08-01T00:00:00","2020-09-01T00:00:00","2020-10-01T00:00:00","2020-11-01T00:00:00","2020-12-01T00:00:00","2021-01-01T00:00:00","2021-02-01T00:00:00","2021-03-01T00:00:00","2021-04-01T00:00:00","2021-06-01T00:00:00","2021-07-01T00:00:00","2021-08-01T00:00:00","2021-10-01T00:00:00","2021-11-01T00:00:00","2021-12-01T00:00:00","2022-01-01T00:00:00","2022-02-01T00:00:00","2022-03-01T00:00:00","2022-04-01T00:00:00","2022-05-01T00:00:00","2022-06-01T00:00:00","2022-07-01T00:00:00","2022-08-01T00:00:00","2022-09-01T00:00:00","2022-10-01T00:00:00","2022-11-01T00:00:00","2022-12-01T00:00:00","2023-01-01T00:00:00","2023-02-01T00:00:00","2023-03-01T00:00:00","2023-04-01T00:00:00","2023-05-01T00:00:00","2023-06-01T00:00:00","2023-07-01T00:00:00","2023-08-01T00:00:00","2023-09-01T00:00:00","2023-10-01T00:00:00","2023-11-01T00:00:00","2023-12-01T00:00:00","2023-12-31T00:00:00","2024-01-31T00:00:00","2024-02-29T00:00:00","2024-03-31T00:00:00","2024-04-30T00:00:00","2024-05-31T00:00:00","2024-06-30T00:00:00","2024-07-31T00:00:00","2024-08-31T00:00:00","2024-09-30T00:00:00","2024-10-31T00:00:00","2024-11-30T00:00:00"],"y":[69231.380595,68773.89147714584,68360.67549972917,67903.18635790091,67460.45493032516,67002.96578455599,66560.23435316647,66102.7452001216,65645.25604707672,65202.52461608183,64745.03547072043,64302.304039725546,63844.81488497032,63387.32573021509,62974.111741356755,62516.62482512076,62074.15028470273,61616.92659293742,61174.599492447305,60717.52815527419,60260.476965464775,59818.16936242342,59361.16235382193,58918.89750678823,58462.30554405824,58005.71358132825,57579.459551634296,56227.205388467264,55786.25294395628,55845.426241968526,55904.59953998079,55962.22168624271,56021.76457071337,56079.62901962571,56139.4222835018,56199.97471618358,56254.66723602518,56316.19768834181,56437.273739674536,56498.9049066448,56562.59044584738,57866.72631211748,58529.483883500645,59171.99530898736,59835.92378199031,60499.852254993246,61099.9038066838,61764.24659605548,62407.453102189276,63072.0998251942,63715.346824712215,64380.03539088082,65044.72399583595,65687.97103288931,66352.65967046982,66995.90673909611,67660.59537667662,68325.28401425714,68925.64794497502,69590.33658255551,70233.58365118182,70898.27228876232,71541.51935738862,72206.20799496914,72870.89663254963,73514.14370117594,74178.83233875645,74822.07940738274,75465.32647600904,76130.01511358956,76751.82061326165,77416.50925084215,78059.75631946845,78724.44495704895,79367.69202567526,80032.38066325577,80697.06930083627,81340.31636946258,82005.00500704307,82648.25207566938],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"rgba(0, 114, 178, 0.2)","width":0},"mode":"lines","name":"trend_upper","x":["2018-01-01T00:00 ...

# %%
from prophet.diagnostics import cross_validation,performance_metrics

# %%
df_cv=cross_validation(model,initial='730 days',period='90 days',horizon='30 days')
df_p=performance_metrics(df_cv)
# Out:
# INFO:prophet:Making 15 forecasts with cutoffs between 2020-01-31 00:00:00 and 2023-11-01 00:00:00
#   0%|          | 0/15 [00:00<?, ?it/s]
# INFO:prophet:n_changepoints greater than number of observations. Using 19.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/xugt07_8.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/gfaeseks.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6651', 'data', 'file=/tmp/tmphtb_b57b/xugt07_8.json', 'init=/tmp/tmphtb_b57b/gfaeseks.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modellxpdo6w8/prophet_model-20240618065156.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:51:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 21.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/r3w1qmro.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/nq657dtr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=1705', 'data', 'file=/tmp/tmphtb_b57b/r3w1qmro.json', 'init=/tmp/tmphtb_b57b/nq657dtr.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modelhen8xdck/prophet_model-20240618065156.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:56 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:51:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:n_changepoints greater than number of observations. Using 23.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/8m5wi5r_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/ibqx56vs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36812', 'data', 'file=/tmp/tmphtb_b57b/8m5wi5r_.json', 'init=/tmp/tmphtb_b57b/ibqx56vs.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modelwmsvcw6h/prophet_model-20240618065157.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:51:57 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/gi0dqeaf.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/8bq5u8kr.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68267', 'data', 'file=/tmp/tmphtb_b57b/gi0dqeaf.json', 'init=/tmp/tmphtb_b57b/8bq5u8kr.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modelmk0pfqlo/prophet_model-20240618065157.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:51:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/gg0rbgs6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/othulxqq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=20928', 'data', 'file=/tmp/tmphtb_b57b/gg0rbgs6.json', 'init=/tmp/tmphtb_b57b/othulxqq.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_model7st670aw/prophet_model-20240618065158.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:51:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/vwf9hfgo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/dlwojwx8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40973', 'data', 'file=/tmp/tmphtb_b57b/vwf9hfgo.json', 'init=/tmp/tmphtb_b57b/dlwojwx8.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_model4k9w_noi/prophet_model-20240618065158.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:51:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/xu8carsm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/4_gblz1n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=66988', 'data', 'file=/tmp/tmphtb_b57b/xu8carsm.json', 'init=/tmp/tmphtb_b57b/4_gblz1n.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modeljs7jtdhh/prophet_model-20240618065158.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:51:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/73_pfiyh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/so2f6lo7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=27475', 'data', 'file=/tmp/tmphtb_b57b/73_pfiyh.json', 'init=/tmp/tmphtb_b57b/so2f6lo7.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modelmhjvbs6r/prophet_model-20240618065159.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:51:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/bgr6nppi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/0u9l4kpm.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45959', 'data', 'file=/tmp/tmphtb_b57b/bgr6nppi.json', 'init=/tmp/tmphtb_b57b/0u9l4kpm.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modelry1sl0av/prophet_model-20240618065159.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:51:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/loeumqke.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/csynoqh6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=11544', 'data', 'file=/tmp/tmphtb_b57b/loeumqke.json', 'init=/tmp/tmphtb_b57b/csynoqh6.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modeltfs0htry/prophet_model-20240618065159.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:51:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:52:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/lodrq3yt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/fb_w2_e7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23211', 'data', 'file=/tmp/tmphtb_b57b/lodrq3yt.json', 'init=/tmp/tmphtb_b57b/fb_w2_e7.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modeluwq1kz41/prophet_model-20240618065200.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:52:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:52:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/pi3m17x6.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/04b0ti_v.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=31654', 'data', 'file=/tmp/tmphtb_b57b/pi3m17x6.json', 'init=/tmp/tmphtb_b57b/04b0ti_v.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modelsn_rmc7s/prophet_model-20240618065200.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:52:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:52:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/4g614aye.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/hbdcx1ky.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4128', 'data', 'file=/tmp/tmphtb_b57b/4g614aye.json', 'init=/tmp/tmphtb_b57b/hbdcx1ky.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modely4po_4o5/prophet_model-20240618065201.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:52:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:52:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/ijibixjz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/33o2enke.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74885', 'data', 'file=/tmp/tmphtb_b57b/ijibixjz.json', 'init=/tmp/tmphtb_b57b/33o2enke.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_model6j0hcv00/prophet_model-20240618065201.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:52:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:52:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/uff5tdjv.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmphtb_b57b/9ii1qzmo.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=82416', 'data', 'file=/tmp/tmphtb_b57b/uff5tdjv.json', 'init=/tmp/tmphtb_b57b/9ii1qzmo.json', 'output', 'file=/tmp/tmphtb_b57b/prophet_modelyuhpn8sa/prophet_model-20240618065202.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 06:52:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 06:52:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
df_p
# Out:
#   horizon           mse          rmse           mae      mape     mdape  \
# 0  1 days  1.594884e+08  12628.869710  12628.869710  0.206395  0.206395
# 1 20 days  3.604771e+08  18986.233335  18938.868964  0.284808  0.284808
# 2 22 days  3.565728e+08  18883.135308  18883.135308  0.307508  0.307508
# 3 24 days  5.191996e+08  22785.951953  22785.951953  0.309398  0.309398
# 4 25 days  2.257128e+08  15023.741126  14819.229401  0.229492  0.229492
# 5 26 days  8.110478e+06   2847.890173   2847.890173  0.075093  0.075093
# 6 27 days  1.951187e+08  13968.489508  13968.489508  0.181153  0.181153
# 7 28 days  9.326616e+08  30539.509345  30539.509345  0.485849  0.485849
# 8 29 days  1.208841e+08  10994.732689  10994.732689  0.139918  0.139918
# 9 30 days  2.695016e+08  16416.502959  14783.586663  0.342055  0.222943
#
#       smape  coverage
# 0  0.230145       0.0
# 1  0.332276       0.0
# 2  0.363379       0.0
# 3  0.366022       0.0
# 4  0.238140       0.0
# 5  0.072375       1.0
# 6  0.199195       0.0
# 7  0.641745       0.0
# 8  0.150442       0.0
# 9  0.284801       0.2

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-170-c681187ba639> in <cell line: 1>()
# ----> 1 df['y_hats']=y_hats2
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3938             self._setitem_array(key, value)
#    3939         elif isinstance(value, DataFrame):
# -> 3940             self._set_item_frame_value(key, value)
#    3941         elif (
#    3942             is_list_like(value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    4092
#    4093         if len(value.columns) != 1:
# -> 4094             raise ValueError(
#    4095                 "Cannot set a DataFrame with multiple columns to the single "
#    4096                 f"column {key}"
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column y_hats
